# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import seaborn as sns

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (20, 10)

# %%
saved_style_state = plt.rcParams.copy() #give us a style state to go back to

# %%
"""http://www.healthstats.nsw.gov.au/indicator/mab_fert"""


if os.path.isfile("NSW Births per month 1990-2019.csv"):
    filepath = "NSW Births per month 1990-2019.csv"
    print("loading from file")
else:
    filepath = ""
    print("loading from the internet")

Birth_data = pd.read_csv(filepath)
print("done")
# Out:
# loading from file
# done

# %%
"""https://capegrim.csiro.au/"""


if os.path.isfile("co2_data.csv"):
    filepath = "co2_data.csv"
    print("loading from file")
else:
    filepath = ""
    print("loading from the internet")

co2_data = pd.read_csv(filepath)
print("done")
# Out:
# loading from file
# done

# %%
if os.path.isfile("Monthly mean maximum temperature Australia 1990 - 2019 - Sheet1.csv"):
    filepath = "Monthly mean maximum temperature Australia 1990 - 2019 - Sheet1.csv"
    print("loading from file")
else:
    filepath = ""
    print("loading from the internet")

Temp_data = pd.read_csv(filepath)
print("done")
# Out:
# loading from file
# done

# %%
if os.path.isfile("fert_data.csv"):
    filepath = "fert_data.csv"
    print("loading from file")
else:
    filepath = ""
    print("loading from the internet")

Fertility_data_read = pd.read_csv(filepath)
fert_data = Fertility_data_read.iloc[::-1]

print("done")
# Out:
# loading from file
# done

# %%
if os.path.isfile("Monthly rainfall Australia 1990 - 2019.csv"):
    filepath = "Monthly rainfall Australia 1990 - 2019.csv"
    print("loading from file")
else:
    filepath = ""
    print("loading from the internet")

Rainfall_data = pd.read_csv(filepath)
print("done")
# Out:
# loading from file
# done

# %%
if os.path.isfile("climate_change_searches.csv"):
    filepath = "climate_change_searches.csv"
    print("loading from file")
else:
    filepath = ""
    print("loading from the internet")

climate_change_search = pd.read_csv(filepath)
print("done")
# Out:
# loading from file
# done

# %%
if os.path.isfile("australia-population-2021-08-02.csv"):
    filepath = "australia-population-2021-08-02.csv"
    print("loading from file")
else:
    filepath = ""
    print("loading from the internet")

australia_birth_data = pd.read_csv(filepath)
print("done")
# Out:
# loading from file
# done

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
"""
DATA SETS

Monthly Mean Max Temperature: http://www.bom.gov.au/jsp/ncc/cdio/weatherData/av?p_nccObsCode=36&p_display_type=dataFile&p_startYear=&p_c=&p_stn_num=066062

Monthly Rainfall: http://www.bom.gov.au/jsp/ncc/cdio/weatherData/av?p_nccObsCode=139&p_display_type=dataFile&p_startYear=&p_c=&p_stn_num=066062

Births, by Year and Month of Occurence: https://stat.data.abs.gov.au/Index.aspx?DataSetCode=BIRTHS_MONTH_OCCURRENCE#

C02 Levels in Australia: https://capegrim.csiro.au/

Google Searches for "Climate Change" in Australia: https://trends.google.com/trends/explore?date=all&geo=AU&q=climate%20change 

Fertility Rates in Australia: https://datacommons.org/place/country/AUS?utm_medium=explore&mprop=fertilityRate&popt=Person&cpv=gender%2CFemale&hl=en

Australia Birth Rates per 1000 people: https://www.macrotrends.net/countries/AUS/australia/birth-rate 
"""
# Out:
# '\nDATA SETS\n\nMonthly Mean Max Temperature: http://www.bom.gov.au/jsp/ncc/cdio/weatherData/av?p_nccObsCode=36&p_display_type=dataFile&p_startYear=&p_c=&p_stn_num=066062\n\nMonthly Rainfall: http://www.bom.gov.au/jsp/ncc/cdio/weatherData/av?p_nccObsCode=139&p_display_type=dataFile&p_startYear=&p_c=&p_stn_num=066062\n\nBirths, by Year and Month of Occurence: https://stat.data.abs.gov.au/Index.aspx?DataSetCode=BIRTHS_MONTH_OCCURRENCE#\n\nC02 Levels in Australia: https://capegrim.csiro.au/\n\nGoogle Searches for "Climate Change" in Australia: https://trends.google.com/trends/explore?date=all&geo=AU&q=climate%20change \n\nFertility Rates in Australia: https://datacommons.org/place/country/AUS?utm_medium=explore&mprop=fertilityRate&popt=Person&cpv=gender%2CFemale&hl=en\n\nAustralia Birth Rates per 1000 people: https://www.macrotrends.net/countries/AUS/australia/birth-rate \n'

# %%
#DATASETS

# %%
Temp_data
# Out:
#       January  February  March  April   May  June  July  August  September  \
# 1990     25.5      25.4   25.3   23.1  21.3  17.4  17.3    17.5       19.4
# 1991     29.1      28.2   25.6   23.1  20.0  19.5  17.0    18.8       21.5
# 1992     25.3      25.0   25.4   22.5  19.7  17.3  17.8    18.1       19.7
# 1993     26.5      27.3   24.7   23.6  20.3  17.3  17.6    18.9       19.8
# 1994     28.2      26.3   23.5   23.2  21.2  18.1  18.0    18.7       21.7
# 1995     24.8      25.1   25.1   22.0  20.2  17.5  16.8    21.3       19.3
# 1996     25.4      25.2   24.6   23.6  21.0  18.3  17.2    18.9       21.7
# 1997     24.1      26.3   25.7   24.4  20.1  18.0  16.7    18.7       19.4
# 1998     27.6      29.0   27.0   23.4  20.1  17.6  16.2    18.1       22.1
# 1999     26.6      26.1   25.7   21.7  20.9  17.8  17.7    18.8       20.9
# 2000     24.8      27.5   25.3   23.4  20.4  17.6  18.3    18.8       22.7
# ...

# %%
Birth_data
# Out:
#       January  February  March  April  May   June  July   August  September   \
# 1990     7349      6866   7717   7443  7617  7423   7609    7751        7871
# 1991     7334      6861   7712   7534  7644  7334   7524    7746        7488
# 1992     7700      7309   7843   7510  7643  7563   8021    7678        7924
# 1993     7428      6958   7913   7413  7543  7499   7624    7505        7682
# 1994     7558      6949   8232   7278  7509  7194   7629    7656        7821
# 1995     7345      6947   7898   7155  7786  7358   7661    7764        7580
# 1996     7246      6939   7396   7086  7476  7182   7471    7589        7715
# 1997     7638      6771   7466   7132  7414  7360   7589    7442        7801
# 1998     7185      6649   7546   7213  7177  7185   7619    7278        7537
# 1999     7365      6839   7688   7323  7221  7446   7544    7536        7624
# 2000     7528      7060   7658   7097  7651  7218   7276    7625        7444
# ...

# %%
Rainfall_data
# Out:
#         Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct  \
# 1990   84.0  630.6  161.6  320.4  131.2   45.2   67.0  204.8  205.4   46.8
# 1991  120.0   63.4   28.6   53.0  141.2  340.6  108.4    6.0   18.4   11.0
# 1992   66.2  408.6   76.4   60.8   68.2  108.0   14.8   48.0   21.0   70.8
# 1993   61.0  100.2   97.4   66.2   18.6   55.8  104.4   62.0  159.4   59.0
# 1994   52.2   99.2  197.4  140.2   33.2   75.0   76.2   23.2   24.2   50.0
# 1995   95.4   51.0  187.4   28.8  184.0  122.6    5.4    0.0  226.2   46.8
# 1996  150.0   54.8   66.2   43.4  177.8  166.4   54.8  146.2  121.8   23.6
# 1997  185.6  137.0   23.2    5.2  193.8   99.8  180.2   27.2  118.4   49.0
# 1998   99.0   31.0   27.0  328.4  263.8  130.8   86.8  482.6   37.6   37.0
# 1999  178.0  143.0   28.0  244.8   57.4   93.8  181.6  134.8   30.0  205.2
# 2000   55.8   18.6  248.4   64.0   55.8   37.0   25.4   20.6   29.4   79.4
# ...

# %%
co2_data
# Out:
#       CO2(ppm)
# 1990   349.849
# 1991   351.454
# 1992   353.357
# 1993   354.264
# 1994   355.135
# 1995   357.552
# 1996   359.562
# 1997   360.430
# 1998   362.166
# 1999   365.133
# 2000   366.689
# 2001   367.649
# 2002   369.469
# 2003   371.675
# 2004   373.662
# 2005   375.467
# 2006   377.962
# 2007   379.480
# 2008   381.768
# 2009   383.949
# 2010   385.073
# 2011   387.012
# 2012   388.809
# 2013   391.157
# 2014   393.623
# 2015   395.777
# 2016   398.698
# 2017   401.161
# 2018   403.750
# 2019   405.740
# 2020   408.269
# 2021   410.549

# %%
fert_data
# Out:
#       Fertility Rate
# 1990           1.902
# 1991           1.849
# 1992           1.888
# 1993           1.859
# 1994           1.842
# 1995           1.822
# 1996           1.796
# 1997           1.778
# 1998           1.762
# 1999           1.755
# 2000           1.756
# 2001           1.739
# 2002           1.756
# 2003           1.748
# 2004           1.768
# 2005           1.807
# 2006           1.908
# 2007           1.959
# 2008           1.984
# 2009           1.971
# 2010           1.928
# 2011           1.926
# 2012           1.920
# 2013           1.855
# 2014           1.826
# 2015           1.814
# 2016           1.752
# 2017           1.741
# 2018           1.740

# %%
#AVERAGES

# %%
Rainfall_data.mean(axis=0)
# Out:
# Jan     91.540000
# Feb    137.780000
# Mar    117.573333
# Apr    123.860000
# May    101.226667
# Jun    141.220690
# Jul     76.426667
# Aug     79.693333
# Sep     68.153333
# Oct     66.979310
# Nov     88.806667
# Dec     72.066667
# dtype: float64

# %%
Birth_data.mean(axis=0)
# Out:
# January       7671.133333
# February      7171.300000
# March         7934.866667
# April         7553.700000
# May           7801.200000
# June          7570.900000
# July          7855.966667
# August        7814.266667
# September     7892.333333
# October       7902.000000
# November      7313.133333
# December      7290.533333
# dtype: float64

# %%
Temp_data.mean(axis=0)
# Out:
# January      26.943333
# February     26.773333
# March        25.696667
# April        23.566667
# May          20.903333
# June         18.220000
# July         17.903333
# August       19.216667
# September    21.553333
# October      23.186667
# November     24.240000
# December     25.796667
# dtype: float64

# %%
#Maximum

# %%
df = pd.DataFrame(Temp_data, columns = ['January', 'February', 'March','April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])
print(df['January'].max())
print(df['February'].max())
print(df['March'].max())
print(df['April'].max())
print(df['May'].max())
print(df['June'].max())
print(df['July'].max())
print(df['August'].max())
print(df['September'].max())
print(df['October'].max())
print(df['November'].max())
print(df['December'].max())
# Out:
# 29.6
# 29.0
# 27.1
# 26.1
# 23.2
# 19.9
# 19.9
# 21.3
# 24.4
# 25.7
# 26.6
# 28.6

# %%
df = pd.DataFrame(Rainfall_data, columns = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
print(df['Jan'].max())
print(df['Feb'].max())
print(df['Mar'].max())
print(df['Apr'].max())
print(df['May'].max())
print(df['Jun'].max())
print(df['Jul'].max())
print(df['Aug'].max())
print(df['Sep'].max())
print(df['Oct'].max())
print(df['Nov'].max())
print(df['Dec'].max())
# Out:
# 249.8
# 630.6
# 326.6
# 366.8
# 371.4
# 510.6
# 282.2
# 482.6
# 226.2
# 234.0
# 192.8
# 201.6

# %%
df = pd.DataFrame(Birth_data, columns = ['January', 'February', 'March','April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])
print(df['January'].max())
print(df['February'].max())
print(df['March'].max())
print(df['April'].max())
print(df['May'].max())
print(df['June'].max())
print(df['July'].max())
print(df['August'].max())
print(df['September'].max())
print(df['October'].max())
print(df['November'].max())
print(df['December'].max())
# Out:
# 8425
# 7943
# 8589
# 8130
# nan
# 8303
# nan
# 8510
# nan
# nan
# nan
# 8468

# %%
df = pd.DataFrame(Birth_data)
print(df.max())
# Out:
# January       8425
# February      7943
# March         8589
# April         8130
# May           8661
# June          8303
# July          8629
# August        8510
# September     8463
# October       8693
# November      8252
# December      8468
# dtype: int64

# %%
#Minimum

# %%
df = pd.DataFrame(Rainfall_data, columns = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
print(df['Jan'].min())
print(df['Feb'].min())
print(df['Mar'].min())
print(df['Apr'].min())
print(df['May'].min())
print(df['Jun'].min())
print(df['Jul'].min())
print(df['Aug'].min())
print(df['Sep'].min())
print(df['Oct'].min())
print(df['Nov'].min())
print(df['Dec'].min())
# Out:
# 13.6
# 18.0
# 23.2
# 5.2
# 3.0
# 22.0
# 5.4
# 0.0
# 0.2
# 5.8
# 13.2
# 1.6

# %%
df = pd.DataFrame(Birth_data)
print(df.min())
# Out:
# January       7131
# February      6538
# March         6822
# April         7067
# May           7082
# June          6548
# July          7276
# August        7123
# September     7444
# October       7266
# November      6012
# December      2739
# dtype: int64

# %%
df = pd.DataFrame(Temp_data, columns = ['January', 'February', 'March','April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])
print(df['January'].min())
print(df['February'].min())
print(df['March'].min())
print(df['April'].min())
print(df['May'].min())
print(df['June'].min())
print(df['July'].min())
print(df['August'].min())
print(df['September'].min())
print(df['October'].min())
print(df['November'].min())
print(df['December'].min())
# Out:
# 24.1
# 24.8
# 23.5
# 21.5
# 19.5
# 16.8
# 16.2
# 17.3
# 19.3
# 21.1
# 21.7
# 23.1

# %%
df = pd.DataFrame(Birth_data, columns = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])
print(df['January'].min())
print(df['February'].min())
print(df['March'].min())
print(df['April'].min())
print(df['May'].min())
print(df['June'].min())
print(df['July'].min())
print(df['August'].min())
print(df['September'].min())
print(df['October'].min())
print(df['November'].min())
print(df['December'].min())
# Out:
# 7131
# 6538
# 6822
# 7067
# nan
# 6548
# nan
# 7123
# nan
# nan
# nan
# 2739

# %%
#Graph Start

# %%
#Hottest month, coldest month against average
Temperatures = [29.6, 16.2]
Averages = [26.943333, 17.903333]
index = ['Warmest Month - January 2017', 'Coldest Month - July 1998']
df = pd.DataFrame({'Month Temperature (°C)':Temperatures, 
'Month Average (°C)': Averages}, index=index)
ax = df.plot.bar(rot=0, color={"Month Temperature (°C)":"red","Month Average (°C)":"darkorange" })

# %%
#Warmest month, birth rates 9 months later
Births = [7863]
Averages = [7902.000000]
index = ['October 2017']
df = pd.DataFrame({'Month Birth Rate': Births, 'Month Average Birth Rate': Averages}, index=index)
ax = df.plot.bar(rot=0, color={"Month Birth Rate":"green","Month Average Birth Rate":"darkorange"})

#findings: unaffected

# %%
#Coldest month, birth rates 9 months later
Births = [7323]
Averages = [7553.700000]
index = ['April 1999']

df = pd.DataFrame({'Month Birth Rate': Births, 'Month Average Birth Rate': Averages}, index=index)
ax = df.plot.bar(rot=0, color={"Month Birth Rate":"green","Month Average Birth Rate":"darkorange"})

#findings: Decrease in Birth rates

# %%
#Wettest month, driest month against average
Rainfall = [630.6, 0.0]
Averages = [137.780000, 79.693333]
index = ['Wettest Month - Feb 1990', 'Driest Month - August 1995']
df = pd.DataFrame({'Month Rainfall (mm)':Rainfall, 
'Month Rainfall Average (mm)': Averages}, index=index)
ax = df.plot.bar(rot=0, color={"Month Rainfall (mm)":"blue","Month Rainfall Average (mm)":"darkorange" })

# %%
#Wettest month, birth rates 9 months later
Births = [7260]
Averages = [7290.533333]

index = ['December 1990']
df = pd.DataFrame({'Month Birth Rate': Births, 'Month Average Birth Rate': Averages}, index=index)
ax = df.plot.bar(rot=0, color={"Month Birth Rate":"green","Month Average Birth Rate":"darkorange"})

#findings: unaffected

# %%
#Driest month, birth rates 9 months later
Births = [7801.200000]
Averages = [7476]
index = ['May 1996']
df = pd.DataFrame({'Month Birth Rate': Births, 'Month Average Birth Rate': Averages}, index=index)
ax = df.plot.bar(rot=0, color={"Month Birth Rate":"green","Month Average Birth Rate":"darkorange"})

#findings: Increase in birth rates

# %%
#Highest and lowest births, against average
Highest = [8693, 2739]
Averages = [7902.000000, 7290.533333]
index = ['Highest Birth Rate Month - October 2012', 'Lowest Birth Rate Month - December 2019']
df = pd.DataFrame({'Birth Rate':Highest, 
'Month Birth Rate Average': Averages}, index=index)
ax = df.plot.bar(rot=0, color={"Birth Rate":"green","Month Birth Rate Average":"darkorange" })

# %%
#Temperature at month of conception for highest birth rate month
Temperature = [26.1]
Averages = [26.943333]
index = ['January 2012']
df = pd.DataFrame({'Month Temperature (°C)': Temperature,'Month Average Temperature (°C)': Averages}, index=index)
ax = df.plot.bar(rot=0, color={"Month Temperature (°C)":"Red","Month Average Temperature (°C)":"darkorange"})

#findings:Temperature lower than monthly average

# %%
#Temperature at month of conception for lowest birth rate month
Temperature = [26.8]
Averages = [25.696667]
index = ['March 2019']
df = pd.DataFrame({'Month Temperature (°C)': Temperature, 'Month Average Temperature (°C)': Averages}, index=index)
ax = df.plot.bar(rot=0, color={"Month Temperature (°C)":"Red","Month Average Temperature (°C)":"darkorange"})

#findings:Temperature higher than monthly average

# %%
#Rainfall at month of conception for highest birth rate month
Rainfall = [138.8]
Averages = [91.540000]
index = ['January 2012']
df = pd.DataFrame({'Month Rainfall (mm)': Rainfall, 'Month Average Rainfall (mm)': Averages}, index=index)
ax = df.plot.bar(rot=0, color={"Month Rainfall (mm)":"blue","Month Average Rainfall (mm)":"darkorange"})

#findings: Rainfall higher than month average

# %%
#Rainfall at month of conception for lowest birth rate month
Rainfall = [229.2]
Averages = [117.573333]
index = ['March 2019']
df = pd.DataFrame({'Month Rainfall (mm)': Rainfall, 'Month Average Rainfall (mm)': Averages}, index=index)
ax = df.plot.bar(rot=0, color={"Month Rainfall (mm)":"blue","Month Average Rainfall (mm)":"darkorange"})

#findings: Rainfall higher than month average

# %%
#Temp and birth rates change over time (1990-2019)

y1 = Temp_data.mean(axis=1)
y2 = Birth_data.mean(axis=1)

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(y1, 'r-')
ax2.plot(y2, 'g-')

ax1.set_xlabel('Year')
ax1.set_ylabel('Temperature (°C)', color='r')
ax2.set_ylabel('Birth Rates', color='g')

plt.show()
#Increase in Birth rates as decrease in Temperature

# %%
#Yearly Birth Rates against Rainfall 

y1 = Rainfall_data.mean(axis=1)
y2 = Birth_data.mean(axis=1)

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(y1, 'b-')
ax2.plot(y2, 'g-')

ax1.set_xlabel('Year')
ax1.set_ylabel('Rainfall (mm)', color='b')
ax2.set_ylabel('Birth Rates', color='g')

plt.show()
#Decrease in birth rates as increase in Rainfall

# %%
#Rainfall and birth rates change over time (1990-2019)

y1 = Temp_data.mean(axis=1)
y2 = co2_data

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(y1, 'r-')
ax2.plot(y2, 'y-')

ax1.set_xlabel('Year')
ax1.set_ylabel('Temperature (°C)', color='r')
ax2.set_ylabel('CO2(ppm)', color='y')

plt.show()
#Increase in Birth rates as decrease in Temperature

# %%
#yearly fertility rates in aus vs c02 levels in aus
y1 = co2_data
y2 = fert_data

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(y1, 'y-')
ax2.plot(y2, 'purple')

ax1.set_xlabel('Year')
ax1.set_ylabel('CO2(ppm)', color='y')
ax2.set_ylabel('Fertility Rate', color='purple')

plt.show()
#No direct damage to fertility rate

# %%
#yearly fertility rates in aus vs temp in aus
y1 = Temp_data.mean(axis=1)
y2 = fert_data

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(y1, 'r-')
ax2.plot(y2, 'purple')

ax1.set_xlabel('Year')
ax1.set_ylabel('Temperature (°C)', color='r')
ax2.set_ylabel('Fertility Rate', color='purple')

plt.show()
#

# %%
#yearly fertility rates in aus against google searches for "climate change" in aus
y1 = climate_change_search
y2 = fert_data

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(y1, 'teal')
ax2.plot(y2, 'purple')

ax1.set_xlabel('Year')
ax1.set_ylabel('Google searches for "climate change" in Australia', color='teal')
ax2.set_ylabel('Fertility Rates', color='purple')

plt.show()
#

# %%
data={'Average Monthly Temperature at Conception':[17.9,18.2,19.2,20.9,21.5,23.1,23.5,24.2,25.6,25.7,26.7,26.9],
      'Birth Rates 9 months later':[7553,7934,7801,7171,7570,7855,7671,7814,7290,7892,7313,7902]}

df = pd.DataFrame(data = data)
df.plot.scatter(x = 'Average Monthly Temperature at Conception', y = 'Birth Rates 9 months later', s = 100)
# Out:
# <AxesSubplot:xlabel='Average Monthly Temperature at Conception', ylabel='Birth Rates 9 months later'>

# %%
data={'Average Monthly Rainfall at Conception':[66.97931,68.153333,72.066667,76.426667,79.693333,88.806667,91.54,101.226667,117.573333,123.86,137.78,141.22069],
      'Birth Rates 9 months later':[8693,8463,8468,8629,8510,8252,8425,8661,8589,8130,7943,8303]}

df = pd.DataFrame(data = data)
df.plot.scatter(x = 'Average Monthly Rainfall at Conception', y = 'Birth Rates 9 months later', s = 100)
# Out:
# <AxesSubplot:xlabel='Average Monthly Rainfall at Conception', ylabel='Birth Rates 9 months later'>
