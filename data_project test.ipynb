# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import seaborn as sns

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (20, 10)

# %%
saved_style_state = plt.rcParams.copy() #give us a style state to go back to

# %%
"""http://www.healthstats.nsw.gov.au/indicator/mab_fert"""


if os.path.isfile("NSW Births per month 1990-2019.csv"):
    filepath = "NSW Births per month 1990-2019.csv"
    print("loading from file")
else:
    filepath = ""
    print("loading from the internet")

Birth_data = pd.read_csv(filepath)
print("done")
# Out:
# loading from file
# done

# %%
if os.path.isfile("mab_fert.csv"):
    filepath = "mab_fert.csv"
    print("loading from file")
else:
    filepath = ""
    print("loading from the internet")

Fertility_data = pd.read_csv(filepath)
print("done")
# Out:
# loading from file
# done

# %%
if os.path.isfile("Monthly mean maximum temperature Australia 1990 - 2019 - Sheet1.csv"):
    filepath = "Monthly mean maximum temperature Australia 1990 - 2019 - Sheet1.csv"
    print("loading from file")
else:
    filepath = ""
    print("loading from the internet")

Temp_data = pd.read_csv(filepath)
print("done")
# Out:
# loading from file
# done

# %%
if os.path.isfile("Monthly rainfall Australia 1990 - 2019.csv"):
    filepath = "Monthly rainfall Australia 1990 - 2019.csv"
    print("loading from file")
else:
    filepath = ""
    print("loading from the internet")

Rainfall_data = pd.read_csv(filepath)
print("done")
# Out:
# loading from file
# done

# %%
if os.path.isfile("Temp data vs Conception - Sheet1.csv"):
    filepath = "Temp data vs Conception - Sheet1.csv"
    print("loading from file")
else:
    filepath = ""
    print("loading from the internet")

Temp_vs_Births_data = pd.read_csv(filepath)
print("done")
# Out:
# loading from file
# done

# %%
if os.path.isfile("Rainfall data vs Conception - Sheet1.csv"):
    filepath = "Rainfall data vs Conception - Sheet1.csv"
    print("loading from file")
else:
    filepath = ""
    print("loading from the internet")

Rainfall_vs_Births_data = pd.read_csv(filepath)
print("done")
# Out:
# loading from file
# done

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
"""
DATA SETS

Monthly Mean Max Temperature: http://www.bom.gov.au/jsp/ncc/cdio/weatherData/av?p_nccObsCode=36&p_display_type=dataFile&p_startYear=&p_c=&p_stn_num=066062

Monthly Rainfall: http://www.bom.gov.au/jsp/ncc/cdio/weatherData/av?p_nccObsCode=139&p_display_type=dataFile&p_startYear=&p_c=&p_stn_num=066062

Births, by Year and Month of Occurence: https://stat.data.abs.gov.au/Index.aspx?DataSetCode=BIRTHS_MONTH_OCCURRENCE#
"""
# Out:
# '\nDATA SETS\n\nMonthly Mean Max Temperature: http://www.bom.gov.au/jsp/ncc/cdio/weatherData/av?p_nccObsCode=36&p_display_type=dataFile&p_startYear=&p_c=&p_stn_num=066062\n\nMonthly Rainfall: http://www.bom.gov.au/jsp/ncc/cdio/weatherData/av?p_nccObsCode=139&p_display_type=dataFile&p_startYear=&p_c=&p_stn_num=066062\n\nBirths, by Year and Month of Occurence: https://stat.data.abs.gov.au/Index.aspx?DataSetCode=BIRTHS_MONTH_OCCURRENCE#\n'

# %%
"""In this project I wanted to research how weather affects birth rates in NSW. With the impact of climate change I was interested to see if rising temperatures and other changing weather patterns had any correlation to birth rates. I compared datasets on different weather conditions and birth rates in NSW between 1990 and 2019."""
# Out:
# 'In this project I wanted to research how weather affects birth rates in NSW. With the impact of climate change I was interested to see if rising temperatures and other changing weather patterns had any correlation to birth rates. I compared datasets on different weather conditions and birth rates in NSW between 1990 and 2019.'

# %%
Birth_data
# Out:
#           January  February  March  April  May   June  July   August  \
# 1990         7349      6866   7717   7443  7617  7423   7609    7751
# 1991         7334      6861   7712   7534  7644  7334   7524    7746
# 1992         7700      7309   7843   7510  7643  7563   8021    7678
# 1993         7428      6958   7913   7413  7543  7499   7624    7505
# 1994         7558      6949   8232   7278  7509  7194   7629    7656
# 1995         7345      6947   7898   7155  7786  7358   7661    7764
# 1996         7246      6939   7396   7086  7476  7182   7471    7589
# 1997         7638      6771   7466   7132  7414  7360   7589    7442
# 1998         7185      6649   7546   7213  7177  7185   7619    7278
# 1999         7365      6839   7688   7323  7221  7446   7544    7536
# 2000         7528      7060   7658   7097  7651  7218   7276    7625
# 2001         7238      6780   7710   7111  7213  7220   7298    7520
# 2002         7314      6879   7542   7067  7430  6991   7374    7376
# ...

# %%
row_one = Birth_data.iloc[0]
row_one
# Out:
#     January    7349
# February       6866
# March          7717
# April          7443
# May            7617
# June           7423
# July           7609
# August         7751
# September      7871
# October        7913
# November       7368
# December       7260
# Name: 1990, dtype: int64

# %%
Birth_data.mean()
# Out:
#     January    7671.133333
# February       7171.300000
# March          7934.866667
# April          7553.700000
# May            7801.200000
# June           7570.900000
# July           7855.966667
# August         7814.266667
# September      7892.333333
# October        7902.000000
# November       7313.133333
# December       7290.533333
# dtype: float64

# %%
Birth_data.mean().divide(100)
# Out:
#     January    76.711333
# February       71.713000
# March          79.348667
# April          75.537000
# May            78.012000
# June           75.709000
# July           78.559667
# August         78.142667
# September      78.923333
# October        79.020000
# November       73.131333
# December       72.905333
# dtype: float64

# %%
Birth_data.columns
# Out:
# Index(['    January', 'February', 'March', 'April', 'May ', 'June', 'July ',
#        'August', 'September ', 'October ', 'November ', 'December'],
#       dtype='object')

# %%
Birth_data.mean().plot(kind='bar', title='Average Births in NSW between 1990 & 2019 ')
# Out:
# <AxesSubplot:title={'center':'Average Births in NSW between 1990 & 2019 '}>

# %%
ax = Birth_data.plot(lw=2, colormap='jet', marker='.', markersize=10, title='Births in NSW between 1990 & 2019 ')
ax.set_xlabel("Year")
ax.set_ylabel("Births")
# Out:
# Text(0, 0.5, 'Births')

# %%
Birth_data.mean().plot()
# Out:
# <AxesSubplot:>

# %%
Birth_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 1990 to 2019
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0       January  30 non-null     int64
#  1   February     30 non-null     int64
#  2   March        30 non-null     int64
#  3   April        30 non-null     int64
#  4   May          30 non-null     int64
#  5   June         30 non-null     int64
#  6   July         30 non-null     int64
#  7   August       30 non-null     int64
#  8   September    30 non-null     int64
#  9   October      30 non-null     int64
#  10  November     30 non-null     int64
#  11  December     30 non-null     int64
# dtypes: int64(12)
# memory usage: 3.0 KB

# %%
Temp_data
# Out:
#           January  February  March  April   May  June  July  August  \
# 1990         25.5      25.4   25.3   23.1  21.3  17.4  17.3    17.5
# 1991         29.1      28.2   25.6   23.1  20.0  19.5  17.0    18.8
# 1992         25.3      25.0   25.4   22.5  19.7  17.3  17.8    18.1
# 1993         26.5      27.3   24.7   23.6  20.3  17.3  17.6    18.9
# 1994         28.2      26.3   23.5   23.2  21.2  18.1  18.0    18.7
# 1995         24.8      25.1   25.1   22.0  20.2  17.5  16.8    21.3
# 1996         25.4      25.2   24.6   23.6  21.0  18.3  17.2    18.9
# 1997         24.1      26.3   25.7   24.4  20.1  18.0  16.7    18.7
# 1998         27.6      29.0   27.0   23.4  20.1  17.6  16.2    18.1
# 1999         26.6      26.1   25.7   21.7  20.9  17.8  17.7    18.8
# 2000         24.8      27.5   25.3   23.4  20.4  17.6  18.3    18.8
# 2001         27.3      27.3   25.8   24.0  19.9  19.9  17.5    19.5
# 2002         27.2      25.2   25.7   24.3  20.1  18.1  18.5    19.6
# ...

# %%
Temp_data.plot(lw=2, colormap='jet', marker='.', markersize=10, title='Max Temperature in NSW between 1990 & 2019 ')
# Out:
# <AxesSubplot:title={'center':'Max Temperature in NSW between 1990 & 2019 '}>

# %%
Temp_data.columns
# Out:
# Index(['    January', 'February', 'March', 'April', 'May', 'June', 'July',
#        'August', 'September', 'October', 'November', 'December'],
#       dtype='object')

# %%
Temp_data.mean()
# Out:
#     January    26.943333
# February       26.773333
# March          25.696667
# April          23.566667
# May            20.903333
# June           18.220000
# July           17.903333
# August         19.216667
# September      21.553333
# October        23.186667
# November       24.240000
# December       25.796667
# dtype: float64

# %%
Temp_data.mean().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
ax = Temp_data.plot(lw=2, colormap='jet', marker='.', markersize=10, title='Mean Monthly Temperature NSW 1990 - 2019 ')
ax.set_xlabel("Year")
ax.set_ylabel("(°C)")
# Out:
# Text(0, 0.5, '(°C)')

# %%
Rainfall_data
# Out:
#           Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct  \
# 1990     84.0  630.6  161.6  320.4  131.2   45.2   67.0  204.8  205.4   46.8
# 1991    120.0   63.4   28.6   53.0  141.2  340.6  108.4    6.0   18.4   11.0
# 1992     66.2  408.6   76.4   60.8   68.2  108.0   14.8   48.0   21.0   70.8
# 1993     61.0  100.2   97.4   66.2   18.6   55.8  104.4   62.0  159.4   59.0
# 1994     52.2   99.2  197.4  140.2   33.2   75.0   76.2   23.2   24.2   50.0
# 1995     95.4   51.0  187.4   28.8  184.0  122.6    5.4    0.0  226.2   46.8
# 1996    150.0   54.8   66.2   43.4  177.8  166.4   54.8  146.2  121.8   23.6
# 1997    185.6  137.0   23.2    5.2  193.8   99.8  180.2   27.2  118.4   49.0
# 1998     99.0   31.0   27.0  328.4  263.8  130.8   86.8  482.6   37.6   37.0
# 1999    178.0  143.0   28.0  244.8   57.4   93.8  181.6  134.8   30.0  205.2
# 2000     55.8   18.6  248.4   64.0   55.8   37.0   25.4   20.6   29.4   79.4
# ...

# %%
Rainfall_data.columns
# Out:
# Index(['    Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep',
#        'Oct', 'Nov', 'Dec'],
#       dtype='object')

# %%
Rainfall_data.mean()
# Out:
#     Jan     91.540000
# Feb        137.780000
# Mar        117.573333
# Apr        123.860000
# May        101.226667
# Jun        141.220690
# Jul         76.426667
# Aug         79.693333
# Sep         68.153333
# Oct         66.979310
# Nov         88.806667
# Dec         72.066667
# dtype: float64

# %%
Rainfall_data.mean().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
ax = Rainfall_data.plot(lw=2, colormap='jet', marker='.', markersize=10, title='Monthly Rainfall NSW 1990 - 2019')
ax.set_xlabel("Year")
ax.set_ylabel("Rainfall (mm)")
# Out:
# Text(0, 0.5, 'Rainfall (mm)')

# %%
Temp_vs_Births_data
# Out:
#                    Avg Max Temperature (°C)  Avg Births (x300)
# January/September                 26.943333          26.307778
# February/October                  26.773333          26.340000
# March/November                    25.696667          24.377111
# April/December                    23.566667          24.301778
# May/January                       20.903333          25.570444
# June/Febraury                     18.220000          23.904333
# July/March                        17.903333          26.449556
# August/April                      19.216667          25.179000
# September/May                     21.553333          26.004000
# October/June                      23.186667          25.236333
# November/July                     24.240000          26.186556
# December/August                   25.796667          26.047556

# %%
Temp_vs_Births_data.columns
# Out:
# Index(['Avg Max Temperature (°C)', 'Avg Births (x300)'], dtype='object')

# %%
"""['January/September', 'February/October', 'March/November', 'April/December', 'May/January', 'June/Febraury', 'July/March', 'August/April', 'September/May', 'October/June', 'November/July', 'December/August']"""

Temp_vs_Births_data.columns
# Out:
# Index(['Avg Max Temperature (°C)', 'Avg Births (x300)'], dtype='object')

# %%
ax = Temp_vs_Births_data.plot(kind='barh', color=['red', 'green'],  title = 'Avg Max Temperature / Avg Births at Month of Conception (1990-2019)')
ax.invert_yaxis()

# %%
Rainfall_vs_Births_data
# Out:
#                    Avg Rainfall (mm)  Avg Births (x100)
# January/September          91.540000          76.711333
# February/October          137.780000          71.713000
# March/November            117.573333          79.348667
# April/December            123.860000          75.537000
# May/January               101.226667          78.012000
# June/Febraury             141.220690          75.709000
# July/March                 76.426667          78.559667
# August/April               79.693333          78.142667
# September/May              68.153333          78.923333
# October/June               66.979310          79.020000
# November/July              88.806667          73.131333
# December/August            72.066667          72.905333

# %%
ax = Rainfall_vs_Births_data.plot(kind='barh', color=['blue', 'green'],  title = 'Avg Max Temperature / Avg Births at Month of Conception (1990-2019)')
ax.invert_yaxis()

# %%
row_one = Birth_data.iloc[0]
row_one.plot

# %%
Birth_data.head(10)
# Out:
#           January  February  March  April  May   June  July   August  \
# 1990         7349      6866   7717   7443  7617  7423   7609    7751
# 1991         7334      6861   7712   7534  7644  7334   7524    7746
# 1992         7700      7309   7843   7510  7643  7563   8021    7678
# 1993         7428      6958   7913   7413  7543  7499   7624    7505
# 1994         7558      6949   8232   7278  7509  7194   7629    7656
# 1995         7345      6947   7898   7155  7786  7358   7661    7764
# 1996         7246      6939   7396   7086  7476  7182   7471    7589
# 1997         7638      6771   7466   7132  7414  7360   7589    7442
# 1998         7185      6649   7546   7213  7177  7185   7619    7278
# 1999         7365      6839   7688   7323  7221  7446   7544    7536
#
#       September   October   November   December
# 1990        7871      7913       7368      7260
# 1991        7488      7625       6886      7178
# 1992        7924      7880       7066      7242
# ...

# %%
sns.set_theme(style="dark")

cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
g = sns.relplot(
    data = Birth_data
)
g.ax.xaxis.grid(True, "minor", linewidth=1)
g.ax.yaxis.grid(True, "minor", linewidth=1)
g.despine(left=True, bottom=True)

# %%
Birth_data
# Out:
#           January  February  March  April  May   June  July   August  \
# 1990         7349      6866   7717   7443  7617  7423   7609    7751
# 1991         7334      6861   7712   7534  7644  7334   7524    7746
# 1992         7700      7309   7843   7510  7643  7563   8021    7678
# 1993         7428      6958   7913   7413  7543  7499   7624    7505
# 1994         7558      6949   8232   7278  7509  7194   7629    7656
# 1995         7345      6947   7898   7155  7786  7358   7661    7764
# 1996         7246      6939   7396   7086  7476  7182   7471    7589
# 1997         7638      6771   7466   7132  7414  7360   7589    7442
# 1998         7185      6649   7546   7213  7177  7185   7619    7278
# 1999         7365      6839   7688   7323  7221  7446   7544    7536
# 2000         7528      7060   7658   7097  7651  7218   7276    7625
# 2001         7238      6780   7710   7111  7213  7220   7298    7520
# 2002         7314      6879   7542   7067  7430  6991   7374    7376
# ...

# %%
sns.histplot(data=Birth_data)
plt.ylim(0, 10)
# Out:
# (0.0, 10.0)

# %%
Fertility_data
# Out:
#                                                                                                                     Total fertility rate, NSW
#  Year  Total fertility rate"  Crude birth rate per 1,000 population General fertility rate  Population  Female population of childbearing age
#  2001  1.78                   12.98                                  51.69                  6,530,349                               1,639,763
#  2002  1.78                   12.90                                  51.48                  6,580,807                               1,648,892
#  2003  1.79                   12.89                                  51.56                  6,620,715                               1,654,994
#  2004  1.77                   12.70                                  50.97                  6,650,735                               1,656,861
# ...

# %%
Birth_data.iloc[:, lambda df: [0]]
# Out:
#           January
# 1990         7349
# 1991         7334
# 1992         7700
# 1993         7428
# 1994         7558
# 1995         7345
# 1996         7246
# 1997         7638
# 1998         7185
# 1999         7365
# 2000         7528
# 2001         7238
# 2002         7314
# 2003         7131
# 2004         7404
# 2005         7183
# 2006         7284
# 2007         8065
# 2008         7964
# 2009         7899
# 2010         8117
# 2011         8167
# 2012         8384
# 2013         8425
# 2014         7655
# 2015         8210
# 2016         7912
# 2017         8166
# 2018         8124
# 2019         7816

# %%
x = Birth_data.iloc[:, lambda df: [1,5]]
x.plot(kind="bar", title="February vs October Birth Rates NSW")
# Out:
# <AxesSubplot:title={'center':'February vs October Birth Rates NSW'}>

# %%
x = Birth_data.iloc[:, lambda df: [1,5]]
x.plot(kind="area",stacked="False", title="February vs October Birth Rates NSW")
x.plot.area(stacked=False)
# Out:
# <AxesSubplot:>

# %%
df = [Temp_data, Birth_data]
df_final = pd.concat(df)

# %%
df_final.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
Birth_data.plot(kind="line")
# Out:
# <AxesSubplot:>

# %%
Temp_data.plot(kind="line")
# Out:
# <AxesSubplot:>

# %%
Group_January = Temp_data.iloc[27, 0], Birth_data.iloc[27, 9]
Group_2 = ['February', 'November']
Group_3 = ['March', 'December']
Group_4 = ['April', 'January']
Group_5 = ['May', 'February']
Group_6 = ['June', 'March']
Group_7 = ['July', 'April']
Group_8 = ['August', 'May']
Group_9 = ['September', 'June']
Group_10 = ['October', 'July']
Group_11 = ['November', 'August']
Group_12 = ['December', 'September']

# %%
Group_jan = Temp_data.iloc[27, 0], Birth_data.iloc[27, 9]
Group_feb = Temp_data.iloc[8, 1], Birth_data.iloc[8, 9]
Group_3 = ['March', 'December']
Group_4 = ['April', 'January']
Group_5 = ['May', 'February']
Group_6 = ['June', 'March']
Group_7 = ['July', 'April']
Group_8 = ['August', 'May']
Group_9 = ['September', 'June']
Group_10 = ['October', 'July']
Group_11 = ['November', 'August']
Group_12 = ['December', 'September']

# %%
#yearly birth rates in NSW vs c02 levels in aus

y1 = co2_data
y2 = Birth_data.mean(axis=1)

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(y1, 'y-')
ax2.plot(y2, 'g-')

ax1.set_xlabel('Year')
ax1.set_ylabel('CO2(ppm)', color='y')
ax2.set_ylabel('Birth Rates', color='g')

plt.show()
#

# %%
print(Temp_data.iloc[27, 0], Rainfall_data.iloc[27, 0], Birth_data.iloc[27, 9])
